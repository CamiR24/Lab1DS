# %% [markdown]
# # Catch22 serie Marítima

# %%
import pandas as pd
import pycatch22
import os

# %%
def cargar_serie(path):
    s = pd.read_csv(path, index_col=0, parse_dates=True)['Marítima']
    s = s.asfreq('MS')
    return s

train_serie = cargar_serie('../../Datos/via_ingreso_maritima.csv')
print(f"Serie: Marítima | Train: {len(train_serie)} obs | {train_serie.index.min().date()} a {train_serie.index.max().date()}")

# --- Extraer las 22 caracteristicas de catch22 ---
resultado = pycatch22.catch22_all(train_serie.tolist(), catch24=False)
fila = dict(zip(resultado['names'], resultado['values']))
fila['serie'] = 'Marítima'

df_catch22 = pd.DataFrame([fila]).set_index('serie')
print(df_catch22.T)

os.makedirs('../../catch22_features', exist_ok=True)
df_catch22.to_csv('../../catch22_features/catch22_maritima.csv')
print("\nGuardado: ../../catch22_features/catch22_maritima.csv")
# Out:
# Serie: Marítima | Train: 210 obs | 2009-01-01 a 2026-06-01
# serie                                         Marítima
# DN_HistogramMode_5                           -0.514655
# DN_HistogramMode_10                          -0.742927
# CO_f1ecac                                     2.449991
# CO_FirstMin_ac                                6.000000
# CO_HistogramAMI_even_2_5                      0.156461
# CO_trev_1_num                                -0.093314
# MD_hrv_classic_pnn40                          0.641148
# SB_BinaryStats_mean_longstretch1             26.000000
# SB_TransitionMatrix_3ac_sumdiagcov            0.007733
# PD_PeriodicityWang_th0_01                    11.000000
# CO_Embed2_Dist_tau_d_expfit_meandiff          0.157638
# IN_AutoMutualInfoStats_40_gaussian_fmmi       4.000000
# FC_LocalSimple_mean1_tauresrat                0.200000
# DN_OutlierInclude_p_001_mdrmd                 0.033333
# DN_OutlierInclude_n_001_mdrmd                 0.514286
# SP_Summaries_welch_rect_area_5_1              0.725599
# SB_BinaryStats_diff_longstretch0              5.000000
# SB_MotifThree_quantile_hh                     1.908973
# SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1   0.857143
# SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1        0.142857
# SP_Summaries_welch_rect_centroid              0.515418
# FC_LocalSimple_mean3_stderr                   0.887796
#
# Guardado: ../../catch22_features/catch22_maritima.csv
