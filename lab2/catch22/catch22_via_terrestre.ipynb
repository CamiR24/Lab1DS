# %% [markdown]
# # Catch22 serie Vía Terrestre

# %%
import pandas as pd
import pycatch22
import os

# %%
def cargar_serie(path):
    s = pd.read_csv(path, index_col=0, parse_dates=True)['Viajero']
    s = s.asfreq('MS')
    return s

full_serie = cargar_serie('../../Datos/via_ingreso_terrestre.csv')
print(f"Serie: Vía Terrestre | {len(full_serie)} obs | {full_serie.index.min().date()} a {full_serie.index.max().date()}")

# --- Extraer las 22 caracteristicas de catch22 ---
resultado = pycatch22.catch22_all(full_serie.tolist(), catch24=False)
fila = dict(zip(resultado['names'], resultado['values']))
fila['serie'] = 'Vía Terrestre'

df_catch22 = pd.DataFrame([fila]).set_index('serie')
print(df_catch22.T)

# --- Guardar en carpeta compartida para armar la matriz despues ---
os.makedirs('../../catch22_features', exist_ok=True)
df_catch22.to_csv('../../catch22_features/catch22_via_terrestre.csv')
print(f"\nGuardado: ../../catch22_features/catch22_via_terrestre.csv")
# Out:
# Serie: Vía Terrestre | 210 obs | 2009-01-01 a 2026-06-01
# serie                                        Vía Terrestre
# DN_HistogramMode_5                               -0.547059
# DN_HistogramMode_10                              -0.781574
# CO_f1ecac                                         8.996925
# CO_FirstMin_ac                                    3.000000
# CO_HistogramAMI_even_2_5                          0.537476
# CO_trev_1_num                                    -0.087833
# MD_hrv_classic_pnn40                              0.909091
# SB_BinaryStats_mean_longstretch1                 30.000000
# SB_TransitionMatrix_3ac_sumdiagcov                0.005510
# PD_PeriodicityWang_th0_01                         3.000000
# CO_Embed2_Dist_tau_d_expfit_meandiff              0.301648
# IN_AutoMutualInfoStats_40_gaussian_fmmi           2.000000
# FC_LocalSimple_mean1_tauresrat                    0.055556
# DN_OutlierInclude_p_001_mdrmd                     0.257143
# DN_OutlierInclude_n_001_mdrmd                     0.309524
# SP_Summaries_welch_rect_area_5_1                  0.834162
# SB_BinaryStats_diff_longstretch0                  6.000000
# SB_MotifThree_quantile_hh                         1.768209
# SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1       0.761905
# SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1            0.833333
# SP_Summaries_welch_rect_centroid                  0.122718
# FC_LocalSimple_mean3_stderr                       0.604538
#
# Guardado: ../../catch22_features/catch22_via_terrestre.csv
