# %% [markdown]
# # Catch22 serie La Aurora

# %%
import pandas as pd
import pycatch22
import os

# %%
def cargar_serie(path):
    s = pd.read_csv(path, index_col=0, parse_dates=True)['Viajero']
    s = s.asfreq('MS')
    return s

train_serie = cargar_serie('../../Datos/la_aurora.csv')
print(f"Serie: La Aurora | {len(train_serie)} obs | {train_serie.index.min().date()} a {train_serie.index.max().date()}")

# --- Extraer las 22 caracteristicas de catch22 ---
resultado = pycatch22.catch22_all(train_serie.tolist(), catch24=False)
fila = dict(zip(resultado['names'], resultado['values']))
fila['serie'] = 'La Aurora'

df_catch22 = pd.DataFrame([fila]).set_index('serie')
print(df_catch22.T)

# --- Guardar en carpeta compartida para armar la matriz despues ---
os.makedirs('../../catch22_features', exist_ok=True)
df_catch22.to_csv('../../catch22_features/catch22_la_aurora.csv')
print("\nGuardado: ../../catch22_features/catch22_la_aurora.csv")
# Out:
# Serie: La Aurora | 210 obs | 2009-01-01 a 2026-06-01
# serie                                        La Aurora
# DN_HistogramMode_5                           -0.401319
# DN_HistogramMode_10                          -0.117716
# CO_f1ecac                                     6.601760
# CO_FirstMin_ac                               10.000000
# CO_HistogramAMI_even_2_5                      0.203560
# CO_trev_1_num                                -0.162875
# MD_hrv_classic_pnn40                          0.947368
# SB_BinaryStats_mean_longstretch1             34.000000
# SB_TransitionMatrix_3ac_sumdiagcov            0.010204
# PD_PeriodicityWang_th0_01                    11.000000
# CO_Embed2_Dist_tau_d_expfit_meandiff          0.212207
# IN_AutoMutualInfoStats_40_gaussian_fmmi       9.000000
# FC_LocalSimple_mean1_tauresrat                0.071429
# DN_OutlierInclude_p_001_mdrmd                 0.188095
# DN_OutlierInclude_n_001_mdrmd                 0.323810
# SP_Summaries_welch_rect_area_5_1              0.758802
# SB_BinaryStats_diff_longstretch0              5.000000
# SB_MotifThree_quantile_hh                     2.000891
# SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1   0.857143
# SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1        0.857143
# SP_Summaries_welch_rect_centroid              0.171806
# FC_LocalSimple_mean3_stderr                   0.737701
#
# Guardado: ../../catch22_features/catch22_la_aurora.csv
