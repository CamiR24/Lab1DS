# %% [markdown]
# # Catch22 serie Total

# %%
import pandas as pd
import pycatch22
import os

# %%
def cargar_serie(path):
    s = pd.read_csv(path, index_col=0, parse_dates=True)['Viajero']
    s = s.asfreq('MS')
    return s

train_serie = cargar_serie('../../Datos/serie_total_viajeros.csv')
print(f"Serie: Total | Train: {len(train_serie)} obs | {train_serie.index.min().date()} a {train_serie.index.max().date()}")

# --- Extraer las 22 caracteristicas de catch22 ---
resultado = pycatch22.catch22_all(train_serie.tolist(), catch24=False)
fila = dict(zip(resultado['names'], resultado['values']))
fila['serie'] = 'Total'

df_catch22 = pd.DataFrame([fila]).set_index('serie')
print(df_catch22.T)

os.makedirs('../catch22_features', exist_ok=True)
df_catch22.to_csv('../../catch22_features/catch22_total.csv')
print("\nGuardado: ../../catch22_features/catch22_total.csv")
# Out:
# Serie: Total | Train: 210 obs | 2009-01-01 a 2026-06-01
# serie                                            Total
# DN_HistogramMode_5                            0.188540
# DN_HistogramMode_10                          -0.580353
# CO_f1ecac                                     8.578892
# CO_FirstMin_ac                               10.000000
# CO_HistogramAMI_even_2_5                      0.453530
# CO_trev_1_num                                -0.126601
# MD_hrv_classic_pnn40                          0.913876
# SB_BinaryStats_mean_longstretch1             30.000000
# SB_TransitionMatrix_3ac_sumdiagcov            0.013774
# PD_PeriodicityWang_th0_01                    11.000000
# CO_Embed2_Dist_tau_d_expfit_meandiff          0.291047
# IN_AutoMutualInfoStats_40_gaussian_fmmi       9.000000
# FC_LocalSimple_mean1_tauresrat                0.055556
# DN_OutlierInclude_p_001_mdrmd                 0.219048
# DN_OutlierInclude_n_001_mdrmd                 0.323810
# SP_Summaries_welch_rect_area_5_1              0.829129
# SB_BinaryStats_diff_longstretch0              6.000000
# SB_MotifThree_quantile_hh                     1.846797
# SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1   0.761905
# SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1        0.857143
# SP_Summaries_welch_rect_centroid              0.147262
# FC_LocalSimple_mean3_stderr                   0.627355
#
# Guardado: ../../catch22_features/catch22_total.csv
